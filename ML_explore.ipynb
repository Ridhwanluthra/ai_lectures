# %%
# just coz I always just do this.
# I am sure this will be used not matter what!
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# check import sklearn
# feel free to import whatever you need
import sklearn

# %% [markdown]
# ## Task - ML Explore
# **At the end you all will submit this jupyter notebook back to me.**
#
# Keep the following point in mind:
# * You can use any or all of the things mentioned in each part
# * Whatever you use you must understand and be prepared for me to check and question!
# * In case you are experimenting and didn't understand the part in any cell mark it with `# Don't Check` at the top of the cell
# * If you feel you can't improve the model any more using the same model change it!
# * If you reach above 98/99% accuracy(used metaphorically) based on a metric, change the metric
# * If you feel highest accuracy has been reached with all metrics or that no more can be done change the dataset!
# * If all this is done or you already know all this work with read world datasets!
# * This is a 3 hour sprint don't stop! Whatever you have at the end submit it and then let the fun(for me xD) begin!
#
# ### Part 1 - Loading Datasets
# [**Use the following datasets**](https://scikit-learn.org/stable/datasets/index.html)
# * Boston
# * Iris
# * Diabetes
# * Digits
# * Wine
#
# ### Part 2 - Data exploration
# * Pandas description
# * Matplotlib visualisation
# * PCA
#
# ### Part 3 - Data Preparation
# * [Preprocessing](https://scikit-learn.org/stable/modules/preprocessing.html#preprocessing)
#     * StandardScalar
#     * MinMaxScalar
#     * Normalization
#     * Discretization
# * Train test split
#
# ### Part 4 - Setup models
# * [Pipeline](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html)
# * Supervised
#     * logistic/linear regression
#     * Support vector machine
#     * Naive bayes
#     * Decision trees
#     * KNN
#     * Ensemble methods
# * Clustering (unsupervised)
#     * k means
#     * Affinity propagation
#
# ### Part 5 - Training
# **This is easy! Just FIT!**
#
# ### Part 6 - Prediction
# **This is easier! Just PREDICT!**
#
# ### Part 7 - Evaluation
# **Even this is easy! PHYCH! NOOOOOOOOO!**
#
# **This according to me is one of the most important parts**
# * [Classification Metrics](https://scikit-learn.org/stable/modules/model_evaluation.html#classification-metrics)
#     * Accuracy Score
#     * F1_score
#     * Confusion matrix
#     * Precision recall curve
# * [Regression Metrics](https://scikit-learn.org/stable/modules/classes.html#regression-metrics)
#     * Mean absolute error
#     * Mean squared error
#     * R2 score
#
# * [Clustering Metrics](https://scikit-learn.org/stable/modules/classes.html#clustering-metrics)
#     * Adjusted rand score
#     * V measure score
#     * Contingency matrix
#
# ### Part 8 - Model Tuning
# **This part is interesting and where all the big bucks lie! If you master this you have mastered machine learning!**
# * Manual evaluation
# * Grid search
# * Randomized search
# * Cross validation (Also an evaluation method)
# * Validation curves
#
# ##### Experiment record sheet - Use this to record everything you do!
# | No. | Name | param 1 | param 2 | param 3 |
# | --- | --- | --- | --- | --- |
# | 1 | first try | 0.2 | 0.1 | 1 |
# | 2 | reduce lr | 0.1 | 0.1 | 1 |
